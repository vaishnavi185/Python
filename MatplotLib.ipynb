# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import numpy as np
# Parameter 1 is an array containing the points on the x-axis.

# Parameter 2 is an array containing the points on the y-axis.
#marker is used to show the points on the graph marker|line|color
#ms is used to set the size of the marker
#mfc is used to set the color of the marker
#mec is used to set the border color of the marker

# %%
x= np.array([6,250])
y=np.array([9,340])

plt.plot(x, y, '*r:',ms=30,mfc="blue", mec="blue")  # star marker, red color, dotted line
plt.show()

# %%
x=np.array([1,2,3,3,4])
y=np.array([9,5,0,2,6])
xlabel="distance"
ylabel="time"
title ="distance vs time"
plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.title(title)
plt.plot(x,y,marker="o")
plt.grid(color="green",linestyle="--") #axis to show grid lines

plt.show()

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)  # the figure has 1 row, 2 columns, and this plot is the first plot.
plt.plot(x, y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral') #c is color, s is size, alpha is transparency, cmap is colormap

plt.colorbar()

plt.show()

# %%
import pandas as pd
data=pd.read_csv("Student Mental health.csv")
data
# Out:
#                Timestamp Choose your gender   Age What is your course?  \
# 0         8/7/2020 12:02             Female  18.0          Engineering
# 1         8/7/2020 12:04               Male  21.0    Islamic education
# 2         8/7/2020 12:05               Male  19.0                  BIT
# 3         8/7/2020 12:06             Female  22.0                 Laws
# 4         8/7/2020 12:13               Male  23.0         Mathemathics
# ..                   ...                ...   ...                  ...
# 96   13/07/2020 19:56:49             Female  21.0                  BCS
# 97   13/07/2020 21:21:42               Male  18.0          Engineering
# 98   13/07/2020 21:22:56             Female  19.0             Nursing
# 99   13/07/2020 21:23:57             Female  23.0     Pendidikan Islam
# 100  18/07/2020 20:16:21               Male  20.0   Biomedical science
#
#     Your current year of Study What is your CGPA? Marital status  \
# ...

# %%
df = pd.DataFrame(data)
# Define "Good" mental health as answering "No" to all three questions
df["mental health"] =df.apply(
    lambda row:"Good" if(row['Do you have Depression?']=='No' and row["Do you have Anxiety?"]=='No' and row["Do you have Panic attack?"]=='No') else "Bad", axis=1
)
df
# Out:
#                Timestamp Choose your gender   Age What is your course?  \
# 0         8/7/2020 12:02             Female  18.0          Engineering
# 1         8/7/2020 12:04               Male  21.0    Islamic education
# 2         8/7/2020 12:05               Male  19.0                  BIT
# 3         8/7/2020 12:06             Female  22.0                 Laws
# 4         8/7/2020 12:13               Male  23.0         Mathemathics
# ..                   ...                ...   ...                  ...
# 96   13/07/2020 19:56:49             Female  21.0                  BCS
# 97   13/07/2020 21:21:42               Male  18.0          Engineering
# 98   13/07/2020 21:22:56             Female  19.0             Nursing
# 99   13/07/2020 21:23:57             Female  23.0     Pendidikan Islam
# 100  18/07/2020 20:16:21               Male  20.0   Biomedical science
#
#     Your current year of Study What is your CGPA? Marital status  \
# ...

# %%
female=df[(df["Choose your gender"]=="Female") & (df["mental health"]=="Good")].count()
male=df[(df["Choose your gender"]=="Male") & (df["mental health"]=="Good")].count()

y=np.array([female["mental health"], male["mental health"]])
labels=["female","male"]
plt.pie(
    y, 
    labels=labels, 
    autopct="%1.1f%%",   # show percentages
    startangle=90,       # start from top
    colors=colors, 
    explode=(0.05, 0)    # highlight first slice a bit
)

plt.title("Good Mental Health by Gender")
plt.axis("equal")  # makes the pie a circle
plt.show()

# %%
import matplotlib.pyplot as plt

# Count "Good" per course
course = (df["mental health"]=="Good").groupby(df["What is your course?"]).sum()
print(course)

# Convert to numpy for plotting
a = course.values
print(a)
labels = course.index
print(labels)
# Plot
plt.bar(labels, a, color="skyblue", edgecolor="black")

plt.title("Good Mental Health by Course")
plt.xlabel("Course")
plt.ylabel("Number of Students with Good Mental Health")
plt.xticks(rotation=8000000)
plt.show()
# Out:
# What is your course?
# ALA                        0
# Accounting                 1
# BCS                        7
# BENL                       0
# BIT                        1
# Banking Studies            1
# Benl                       1
# Biomedical science         4
# Biotechnology              1
# Business Administration    1
# CTS                        0
# Communication              0
# DIPLOMA TESL               0
# Diploma Nursing            1
# ENM                        0
# Econs                      0
# Engine                     2
# Engineering                6
# Fiqh                       0
# Fiqh fatwa                 1
# Human Resources            1
# Human Sciences             0
# IT                         0
# Irkhs                      0
# Islamic Education          1
# Islamic education          0
# KENMS                      0
# KIRKHS                     1
# KOE                        1
# Kirkhs                     1
# Koe                        0
# ...

# %%
avg_age =df[df["mental health"]=="Good"] ["Age"].mean()
avg_age
no_of_students=df.groupby("What is your course?").size()
top_course = no_of_students.idxmax() 
top_count = no_of_students.max()
print(f"The average age of students with good mental health is {avg_age:.2f} years.")
print(f"The course with the highest number of students is {top_course} with {top_count} students.")
# Out:
# The average age of students with good mental health is 20.69 years.
# The course with the highest number of students is BCS with 18 students.

# %%
# depression = df["Do you have Depression?"].value_counts()
# print(depression)
good=df["mental health"].value_counts()
print(good)
percentage=good/len(df)*100
print(percentage)
# Out:
# Bad     64
# Good    37
# Name: mental health, dtype: int64
# Bad     63.366337
# Good    36.633663
# Name: mental health, dtype: float64

# %%
goodmet = df[df["mental health"]=="Good"].groupby("What is your course?").size()
goodmet
# Out:
# What is your course?
# Accounting                 1
# BCS                        7
# BIT                        1
# Banking Studies            1
# Benl                       1
# Biomedical science         4
# Biotechnology              1
# Business Administration    1
# Diploma Nursing            1
# Engine                     2
# Engineering                6
# Fiqh fatwa                 1
# Human Resources            1
# Islamic Education          1
# KIRKHS                     1
# KOE                        1
# Kirkhs                     1
# Mathemathics               1
# Pendidikan Islam           1
# Pendidikan Islam           1
# Psychology                 1
# Radiography                1
# dtype: int64

# %%
total_stu_per_grp= df.groupby("What is your course?").size()
good=df[df["mental health"]=="Good"].groupby("What is your course?").size()
prop=good/total_stu_per_grp*100
top=prop.idxmax()
top_val=prop.max()
print(f"The course with the highest proportion of students with good mental health is {top} with {top_val:.2f}% of its students having good mental health.")
# Out:
# The course with the highest proportion of students with good mental health is Accounting  with 100.00% of its students having good mental health.

# %%
# Group by gender and course, count students with "Good" mental health
ggodmet = df[df["mental health"]=="Good"].groupby(["Choose your gender", "What is your course?"]).size()
ggodmet
notgoodmet=df[df["mental health"]=="Bad"].groupby([ "What is your course?"]).size()
top3=notgoodmet.sort_values(ascending=False).head(3)
top3
# Out:
# What is your course?
# Engineering    11
# BCS            11
# BIT             9
# dtype: int64

# %%
good = data[data["mental health"] == 'Good'].groupby("What is your course?").size()
bad = data[data["mental health"] == 'Bad'].groupby("What is your course?").size()
df = pd.DataFrame({
    "Good mental health": good,
    "Bad mental health": bad
})
df.plot(kind='bar', stacked=True)
plt.title("Good vs Not Good Mental Health by Course")
plt.xlabel("Course")
plt.ylabel("Number of Students")
plt.xticks(rotation=800000005)
plt.legend(title="Mental Health")
plt.show()

# %%
import matplotlib.pyplot as plt

# Count "Good" students by gender
female_good = data[(data["Choose your gender"]=="Female") & (data["mental health"]=="Good")].shape[0]
male_good   = data[(data["Choose your gender"]=="Male") & (data["mental health"]=="Good")].shape[0]

# Prepare values and labels
values = [female_good, male_good]
labels = ["Female", "Male"]
colors = ["#ffcc66", "#66b3ff"]  # optional nice colors

# Only plot if there are students
if sum(values) > 0:
    plt.pie(values, labels=labels, colors=colors, autopct="%1.1f%%", startangle=90)
    plt.title("Proportion of 'Good' Mental Health Students by Gender")
    plt.axis("equal")  # make pie chart circular
    plt.show()
else:
    print("No 'Good' students found. Pie chart cannot be plotted.")

# %%
data=pd.read_csv("Student Mental health.csv")
data.dropna(inplace=True)
data.shape
data.columns
data.dtypes
data.nunique()
data.isnull().sum()
data.rename(columns={"Choose your gender": "Gender"}, inplace=True)
data
data.rename(columns={"What is your course ?":"Course"},inplace=True)
data
# Out:
#                Timestamp  Gender   Age What is your course?  \
# 0         8/7/2020 12:02  Female  18.0          Engineering
# 1         8/7/2020 12:04    Male  21.0    Islamic education
# 2         8/7/2020 12:05    Male  19.0                  BIT
# 3         8/7/2020 12:06  Female  22.0                 Laws
# 4         8/7/2020 12:13    Male  23.0         Mathemathics
# ..                   ...     ...   ...                  ...
# 96   13/07/2020 19:56:49  Female  21.0                  BCS
# 97   13/07/2020 21:21:42    Male  18.0          Engineering
# 98   13/07/2020 21:22:56  Female  19.0             Nursing
# 99   13/07/2020 21:23:57  Female  23.0     Pendidikan Islam
# 100  18/07/2020 20:16:21    Male  20.0   Biomedical science
#
#     Your current year of Study What is your CGPA? Marital status  \
# 0                       year 1        3.00 - 3.49             No
# 1                       year 2        3.00 - 3.49             No
# ...
