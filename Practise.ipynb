# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv("Employee.csv")
df.head()
df.tail()
df.shape
# df.columns
# df.describe()
# Out:
# (4653, 9)

# %%
df.loc[3,"JoiningYear"]=np.nan
df["JoiningYear"].fillna(value=2012, inplace=True)
df.sort_values(by="JoiningYear",ascending=True, inplace=True)
df["JoiningYear"].max()
df.drop_duplicates(inplace=True)
df
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 1846  Bachelors       2012.0  Bangalore            3   27  Female          No
# 3921  Bachelors       2012.0  Bangalore            3   33    Male         Yes
# 722   Bachelors       2012.0  Bangalore            3   26  Female          No
# 3911  Bachelors       2012.0  Bangalore            3   36    Male          No
# 3907  Bachelors       2012.0  Bangalore            3   34    Male          No
# ...         ...          ...        ...          ...  ...     ...         ...
# 564     Masters       2018.0       Pune            3   25    Male          No
# 4114        PHD       2018.0  New Delhi            3   37    Male          No
# 2998  Bachelors       2018.0       Pune            3   31    Male          No
# 3005  Bachelors       2018.0  Bangalore            3   35  Female         Yes
# 2265  Bachelors       2018.0  Bangalore            3   29  Female         Yes
#
# ...

# %%
df[df["Gender"]=="Female"].count()
df[df["Gender"]=="Male"].count()
male_salaries = df[df["Gender"] == "Male"]["PaymentTier"]
f=df[df["Gender"]=="Female"]["Education"]
f=df[(df["Gender"]=="Female") & (df["Education"]=="Masters")].count()
m=df[(df["Gender"]=="Male")& (df["Education"]=="Masters")].count()

mean =df[df["Gender"]=="Female"]["PaymentTier"].mean()
mean
leavecount=df[(df["Gender"]=="Female")&(df["LeaveOrNot"]==0)].count()
leavecount
# Out:
# Education                    621
# JoiningYear                  621
# City                         621
# PaymentTier                  621
# Age                          621
# Gender                       621
# EverBenched                  621
# ExperienceInCurrentDomain    621
# LeaveOrNot                   621
# dtype: int64
